# %% [markdown]
# # Preparation

# %%
# %matplotlib inline
import pandas as pd
import networkx as nx
# import netwulf as nw
import matplotlib.pyplot as plt
import seaborn as sns
import random

import numpy as np
# import matplotlib.lines as mlines

plt.rcParams['font.sans-serif'] = ['Times New Roman']  #防止中文乱码，还可以有Microsoft YaHei, Times New Roman, Arial
plt.rcParams["axes.unicode_minus"] = False   #字符显示，防止负号乱码

import warnings
warnings.filterwarnings('ignore')

# %%
# from infomap import Infomap
# from cdlib import algorithms, NodeClustering

# %%
geo = pd.read_csv("data/NYCTAXI202401-202403.geo")
geo.head()
# Out:
#    geo_id          type                                        coordinates
# 0       0       Polygon  [[['-74.18445300', '40.69499600'], ['-74.18563...
# 1       1  MultiPolygon  [[[['-73.81768667', '40.61493300'], ['-73.8165...
# 2       2       Polygon  [[['-73.84240629', '40.86847474'], ['-73.84280...
# 3       3       Polygon  [[['-73.97464721', '40.71884235'], ['-73.97347...
# 4       4       Polygon  [[['-74.17225508', '40.56170484'], ['-74.17348...

# %%
rel = pd.read_csv("data/NYCTAXI202401-202403.rel")
rel.head()
# Out:
#    rel_id type  origin_id  destination_id     cost
# 0       0  geo          0               0      0.0
# 1       1  geo          0               1  31349.0
# 2       2  geo          0               2  33747.0
# 3       3  geo          0               3  17205.0
# 4       4  geo          0               4  14927.0

# %%
df_total = pd.read_csv("data/total/NYCTAXI_OD_Total.csv")

df_earlymorning = pd.read_csv("data/timeperiod/NYCTAXI_OD_Early Morning.csv")
df_morningrush = pd.read_csv("data/timeperiod/NYCTAXI_OD_Morning Rush.csv")
df_morningtonoon = pd.read_csv("data/timeperiod/NYCTAXI_OD_Morning to Noon.csv")
df_afternoon = pd.read_csv("data/timeperiod/NYCTAXI_OD_Afternoon.csv")
df_eveningrush = pd.read_csv("data/timeperiod/NYCTAXI_OD_Evening Rush.csv")
df_night = pd.read_csv("data/timeperiod/NYCTAXI_OD_Night.csv")

# df_total["flow"].value_counts()
# df_total["origin_id"].nunique()

# %%
df_total
# Out:
#        origin_id  destination_id      flow
# 0              0              47  0.000916
# 1              0              99  0.000458
# 2              0             186  0.000458
# 3              0             208  0.000458
# 4              0             230  0.000458
# ...          ...             ...       ...
# 25966        262             257  0.002290
# 25967        262             258  0.004123
# 25968        262             259  0.017865
# 25969        262             260  0.069629
# 25970        262             261  3.509391
#
# [25971 rows x 3 columns]

# %%
# df_afternoon.drop(columns=["Unnamed: 0"], inplace=True)
df_afternoon["flow"].value_counts()
# Out:
# flow
# 0.002747    4571
# 0.005495    1697
# 0.008242     862
# 0.010989     574
# 0.013736     400
#             ...
# 1.634615       1
# 1.016484       1
# 0.945055       1
# 2.755495       1
# 5.708791       1
# Name: count, Length: 1175, dtype: int64

# %% [markdown]
# # Construct network

# %%
G_total = nx.DiGraph()

G_earlymorning = nx.DiGraph()
G_morningrush = nx.DiGraph()
G_morningtonoon = nx.DiGraph()
G_afternoon = nx.DiGraph()
G_eveningrush = nx.DiGraph()
G_night = nx.DiGraph()

# %%
def construct_graph(G, df):
    for i, row in df.iterrows():
        G.add_edge(row["origin_id"], row["destination_id"], flow=row["flow"])
    # G.add_nodes_from(rel["origin_id"].unique())
    
construct_graph(G_total, df_total)

construct_graph(G_earlymorning, df_earlymorning)
construct_graph(G_morningrush, df_morningrush)
construct_graph(G_morningtonoon, df_morningtonoon)
construct_graph(G_afternoon, df_afternoon)
construct_graph(G_eveningrush, df_eveningrush)
construct_graph(G_night, df_night)

# %%
def saveall_gexf():
    nx.write_gexf(G_total,"data/total/NYCTAXI_OD_Total.gexf")

    nx.write_gexf(G_earlymorning,"data/timeperiod/NYCTAXI_OD_Early Morning.gexf")
    nx.write_gexf(G_morningrush,"data/timeperiod/NYCTAXI_OD_Morning Rush.gexf")
    nx.write_gexf(G_morningtonoon,"data/timeperiod/NYCTAXI_OD_Morning to Noon.gexf")
    nx.write_gexf(G_afternoon,"data/timeperiod/NYCTAXI_OD_Afternoon.gexf")
    nx.write_gexf(G_eveningrush,"data/timeperiod/NYCTAXI_OD_Evening Rush.gexf")
    nx.write_gexf(G_night,"data/timeperiod/NYCTAXI_OD_Night.gexf")
# saveall_gexf()

# %%
# 服务器上不可用
# stylized_network, config = nw.visualize(G_afternoon, plot_in_cell_below=False)
# fig, ax = nw.draw_netwulf(stylized_network, figsize=(10,10))
# plt.savefig("myfigure.pdf")

# %%
# df_afternoon[df_afternoon["destination_id"] == 238]

# %%
# G_afternoon.edges(238,data=True)

# %% [markdown]
# # Basic statistics

# %% [markdown]
# ## calculate

# %%
def get_network_statistics(G):
    # 基本统计量
    num_nodes = G.number_of_nodes()  # 节点数量
    num_edges = G.number_of_edges()  # 边数量

    # 平均度
    avg_degree = sum(dict(G.degree(weight = "flow")).values()) / num_nodes

    in_degrees = [deg for node, deg in G.in_degree(weight = "flow")]
    out_degrees = [deg for node, deg in G.out_degree(weight = "flow")]
    avg_in_degree = sum(in_degrees) / len(in_degrees)
    avg_out_degree = sum(out_degrees) / len(out_degrees)

    # Hubs（度数最高的节点）
    degree_dict = dict(G.degree(weight = "flow"))
    hubs = [node for node, degree in degree_dict.items() if degree == max(degree_dict.values())]
    in_degree_dict = dict(G.in_degree(weight = "flow"))
    in_hubs = [node for node, degree in in_degree_dict.items() if degree == max(in_degree_dict.values())]
    out_degree_dict = dict(G.out_degree(weight = "flow"))
    out_hubs = [node for node, degree in out_degree_dict.items() if degree == max(out_degree_dict.values())]

    # 最短路径长度
    shortest_path_lengths = dict(nx.shortest_path_length(G))

    # 直径（最长的最短路径长度）
    try:
        diameter = nx.diameter(G)
    except:
        diameter = "Network is not connected."

    # 最大连通分量
    largest_component = max(nx.strongly_connected_components(G), key=len)

    return {
        "Number of nodes": num_nodes,
        "Number of edges": num_edges,
        "Average degree": avg_degree,
        "Average inout-degree": avg_in_degree,
        # "Hubs": hubs,
        "In_hubs": in_hubs,
        "Out_hubs": out_hubs,
        # "Shortest path lengths": shortest_path_lengths,
        "Diameter": diameter,
        "Largest component": largest_component,
        "Size of largest component": len(largest_component)
    }

def print_statistics(G):
    # print("-"*45)
    stats = get_network_statistics(G)
    # for key, value in stats.items():
        # print(f"{key}: {value}")
    return stats

# %%
G_total_stats = print_statistics(G_total)

G_earlymorning_stats = print_statistics(G_earlymorning)
G_morningrush_stats = print_statistics(G_morningrush)
G_morningtonoon_stats = print_statistics(G_morningtonoon)
G_afternoon_stats = print_statistics(G_afternoon)
G_eveningrush_stats = print_statistics(G_eveningrush)
G_night_stats = print_statistics(G_night)

# %%
df_statistics = pd.DataFrame(
    [G_total_stats, G_earlymorning_stats, G_morningrush_stats, G_morningtonoon_stats, G_afternoon_stats, G_eveningrush_stats, G_night_stats],
    index=["Total", "Early Morning", "Morning Rush", "Morning to Noon", "Afternoon", "Evening Rush", "Night"]
)
df_statistics
# Out:
#                  Number of nodes  Number of edges  Average degree  \
# Total                        260            25971       23.366514
# Early Morning                255            17371       16.908361
# Morning Rush                 256            14079       30.594716
# Morning to Noon              251             9748       35.205945
# Afternoon                    256            13978       37.096218
# Evening Rush                 256            13322       26.427885
# Night                        257            11224        8.094091
#
#                  Average inout-degree  In_hubs Out_hubs  \
# Total                       11.683257  [235.0]  [160.0]
# Early Morning                8.454181  [160.0]  [235.0]
# Morning Rush                15.297358  [235.0]  [236.0]
# Morning to Noon             17.602973  [235.0]  [160.0]
# Afternoon                   18.548109  [235.0]  [160.0]
# Evening Rush                13.213942   [78.0]  [229.0]
# Night                        4.047045   [78.0]   [78.0]
#
#                                   Diameter  \
# Total            Network is not connected.
# Early Morning    Network is not connected.
# Morning Rush     Network is not connected.
# Morning to Noon  Network is not connected.
# Afternoon        Network is not connected.
# Evening Rush     Network is not connected.
# Night            Network is not connected.
#
#                                                  Largest component  \
# Total            {0.0, 1.0, 2.0, 3.0, 5.0, 6.0, 7.0, 8.0, 9.0, ...
# Early Morning    {0.0, 1.0, 2.0, 3.0, 5.0, 6.0, 7.0, 8.0, 9.0, ...
# Morning Rush     {0.0, 1.0, 2.0, 3.0, 5.0, 6.0, 7.0, 8.0, 9.0, ...
# Morning to Noon  {1.0, 2.0, 3.0, 5.0, 6.0, 7.0, 8.0, 9.0, 10.0,...
# Afternoon        {0.0, 2.0, 3.0, 5.0, 6.0, 7.0, 8.0, 9.0, 10.0,...
# Evening Rush     {1.0, 2.0, 3.0, 5.0, 6.0, 7.0, 8.0, 9.0, 10.0,...
# Night            {0.0, 1.0, 2.0, 3.0, 5.0, 6.0, 8.0, 9.0, 10.0,...
#
#                  Size of largest component
# Total                                  255
# Early Morning                          246
# Morning Rush                           245
# Morning to Noon                        236
# Afternoon                              244
# Evening Rush                           246
# Night                                  241

# %% [markdown]
# ## plot

# %%
with plt.style.context("fivethirtyeight"), sns.plotting_context(context="poster",font_scale=0.5):
    fig,ax = plt.subplots(figsize=(10, 5))
    fig.patch.set_facecolor('white')  # 设置整个图的背景颜色为白色
    line = sns.lineplot(x=df_statistics.index, y="Average inout-degree", data=df_statistics,marker = "o")
    
    ax.set_facecolor('white')    # 设置轴的边框颜色为白色
    for spine in ax.spines.values():
        spine.set_edgecolor('white')
        
    for x, y in zip(df_statistics.index, df_statistics["Average inout-degree"]):
        ax.text(x, y, f'{y:.2f}', color='black', ha='left')
    plt.xlabel("Time Period")
    plt.ylabel("Average Inout-degree")
    plt.title("Average Inout-degree of Different Time Periods",fontsize = 20,weight = "bold")
    plt.tight_layout()
    # plt.savefig("output/plot/Average Inout-degree of Different Time Periods.svg", bbox_inches="tight", transparent=True)
    # plt.savefig("output/plot/Average Inout-degree of Different Time Periods.pdf", bbox_inches="tight", transparent=True)

# %%
networks = [G_earlymorning, G_morningrush, G_morningtonoon, G_afternoon, G_eveningrush, G_night,G_total]  # replace with your actual networks
titles = ["Early Morning", "Morning Rush", "Morning to Noon", "Afternoon", "Evening Rush", "Night","Total"]  # replace with your actual titles

def plot_degree(i,ax):
    G = networks[i]
    in_degree_sequence = [G.in_degree(node,weight = "flow") for node in G if G.in_degree(node,weight = "flow") > 0]
    out_degree_sequence = [G.out_degree(node,weight = "flow") for node in G if G.out_degree(node,weight = "flow") > 0]

    kmin_in = min(in_degree_sequence)
    kmax_in = max(in_degree_sequence)
    bin_edges_in = np.logspace(np.log10(kmin_in), np.log10(kmax_in), num=10)
    density_in, _ = np.histogram(in_degree_sequence, bins=bin_edges_in, density=True)

    kmin_out = min(out_degree_sequence)
    kmax_out = max(out_degree_sequence)
    bin_edges_out = np.logspace(np.log10(kmin_out), np.log10(kmax_out), num=10)
    density_out, _ = np.histogram(out_degree_sequence, bins=bin_edges_out, density=True)

    log_be_in = np.log10(bin_edges_in)
    x_in = 10**((log_be_in[1:] + log_be_in[:-1])/2)
    log_be_out = np.log10(bin_edges_out)
    x_out = 10**((log_be_out[1:] + log_be_out[:-1])/2)

    line1 = sns.lineplot(x=x_in, y=density_in, marker='o', label='In-degree', ax=ax,markersize = 7)
    line2 = sns.lineplot(x=x_out, y=density_out, marker='o', label='Out-degree', ax=ax,markersize = 7)

    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel(r"degree $k$", fontsize=16)
    ax.set_ylabel(r"$P(k)$", fontsize=16)
    ax.set_title(titles[i])
    # ax.legend()
    return line1, line2

# %%
with plt.style.context("fivethirtyeight"), sns.plotting_context(context="poster",font_scale=0.5):
    fig, axs = plt.subplots(2, 3, figsize=(14,10))
    plt.suptitle("Degree Distribution of Different Time Periods", fontsize=30, weight="bold")
    plt.subplots_adjust(top = 0.9)
    fig.patch.set_facecolor('white')
    for i, ax in enumerate(axs.flatten()):
        ax.grid(False)
        (line1, line2) = plot_degree(i, ax)
        ax.set_facecolor('white')
        for spine in ax.spines.values():
            spine.set_edgecolor('white')
        # ax.legend().set_visible(False)
    
    plt.tight_layout()
# plt.savefig("output/plot/Degree distribution of different time periods.svg",bbox_inches="tight",transparent=True)
# plt.savefig("output/plot/Degree distribution of different time periods.pdf",bbox_inches="tight",transparent=True)

# %%
import powerlaw

degrees=np.array(list(dict(G_total.in_degree(weight = "flow")).values()))
results = powerlaw.Fit(degrees);
print(results.power_law.alpha)
print(results.power_law.xmin)

R, p = results.distribution_compare('power_law', 'lognormal_positive')
print(R, p)
# Out:
# Calculating best minimal value for power law fit
# 1.3882606367284551
# 0.14475492441593907
# 1.6785573005272276 0.8044220622863372
# Values less than or equal to 0 in data. Throwing out 0 or negative values

# %%
with plt.style.context("fivethirtyeight"), sns.plotting_context(context="poster",font_scale=0.5):
    fig, ax = plt.subplots(figsize=(7, 5))
    fig.patch.set_facecolor('white')
    ax.set_facecolor('white')
    for spine in ax.spines.values():
        spine.set_edgecolor('white')

    fit = powerlaw.Fit(degrees, discrete=True);
    FigCCDF = fit.plot_ccdf(color='k',alpha=0.2, lw=8, label=r"Empirical");
    fit.power_law.plot_ccdf(color='#177ad3', linestyle='--', lw=3, ax=FigCCDF, label="Powerlaw Fit");

    # adjust the labels
    FigCCDF.set_ylabel("$p(X≥x)$")
    FigCCDF.set_xlabel("$k$")
    handles, labels = FigCCDF.get_legend_handles_labels()
    leg = FigCCDF.legend(handles, labels, loc=3)
    leg.draw_frame(True)
    ax.grid(False)
    plt.title("Powerlaw Fit of Total Network",weight = "bold",fontsize = 20)
    plt.legend(frameon = False)
    plt.tight_layout()
    plt.savefig("output/plot/Powerlaw Fit of Total Network.svg",bbox_inches="tight",transparent=True)
    plt.savefig("output/plot/Powerlaw Fit of Total Network.pdf",bbox_inches="tight",transparent=True)
# Out:
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Calculating best minimal value for power law fit
# xmin progress: 99%

# %% [markdown]
# 假设是直线，他们的幂指数为-1，不合理
#
# The change in slope (steepness) suggests a difference in the way in-degrees and out-degrees are distributed across the network during different times.
#
# There is a noticeable point around the degree range of 0.1 to 1 where the in-degree and out-degree distributions intersect. Below this point, the in-degree is generally higher than the out-degree, while above this point, the out-degree is higher than the in-degree. This transition point can be indicative of different underlying processes governing the degree distributions at lower and higher degrees.
#
# There are more nodes have small out degree, while more nodes have large in degree. 出去的话就是单个单个，但是进去的就是成群结队的多。转折点再degree 等于0.1-1之间。

# %% [markdown]
# # Null model

# %% [markdown]
# ## configuration model

# %%
# def configuration_model_directed(G):
#     in_degrees = [G.in_degree(n) for n in G.nodes()]
#     out_degrees = [G.out_degree(n) for n in G.nodes()]

#     null_model = nx.directed_configuration_model(in_degrees, out_degrees)
#     null_model = nx.DiGraph(null_model)    # 将生成的多重边图转换为简单图

#     # 随机分配边的权重
#     original_weights = [data['flow'] for _, _, data in G.edges(data=True)]
#     for (u, v, data) in null_model.edges(data=True):
#         data['flow'] = random.choice(original_weights)

#     return null_model

# config_model = configuration_model_directed(G_total)

# # print("Edges and weights in the null model:")
# # for (u, v, data) in config_model.edges(data=True):
# #     print(f"({u}, {v}, {data['flow']})")

# %% [markdown]
# ## Degree-Preserving Randomization

# %%
import copy

def degree_preserving_randomization(G, iterations=1000):
    # Copy the original graph to keep degree distribution intact
    null_model = copy.deepcopy(G)
    
    edges = list(null_model.edges(data=True))
    num_edges = len(edges)
    
    for _ in range(iterations):
        # Randomly select two edges
        i, j = random.sample(range(num_edges), 2)
        (u1, v1, data1) = edges[i]
        (u2, v2, data2) = edges[j]
        
        # Swap endpoints to preserve degree distribution
        if u1 != u2 and v1 != v2 and not null_model.has_edge(u1, v2) and not null_model.has_edge(u2, v1):
            null_model.remove_edge(u1, v1)
            null_model.remove_edge(u2, v2)
            null_model.add_edge(u1, v2, flow=data1['flow'])
            null_model.add_edge(u2, v1, flow=data2['flow'])
            
            # Update edge list
            edges[i] = (u1, v2, data1)
            edges[j] = (u2, v1, data2)

    # Shuffle the weights randomly
    weights = [data['flow'] for _, _, data in null_model.edges(data=True)]
    random.shuffle(weights)
    
    for (u, v, data), weight in zip(null_model.edges(data=True), weights):
        data['flow'] = weight

    return null_model


random_swap_model = degree_preserving_randomization(G_total, iterations=1000)

# print("Edges and weights in the null model:")
# for (u, v, data) in random_swap_model.edges(data=True):
#     print(f"({u}, {v}, {data['flow']})")

# %% [markdown]
# # Structure

# %% [markdown]
# ## Clustering coefficient

# %% [markdown]
# 在有向图中，节点i的聚类系数定义为所有可能的有向三元组（即i -> j, j -> k, k -> i）的比例，其中j和k是i的邻居。一个有向三元组是一个节点对的有序三元组。nx.average_clustering()函数默认会将有向图视为无向图进行计算。

# %%
# # avg_clustering = nx.average_clustering(G, count_zeros=False)
# G_total_avcl = nx.average_clustering(G_total,weight="flow")
# # config_avcl = nx.average_clustering(config_model,weight="flow")
# random_swap_avcl = nx.average_clustering(random_swap_model,weight="flow")

# G_total_cl = nx.clustering(G_total,weight="flow")
# # config_cl = nx.clustering(config_model,weight="flow")
# random_swap_cl = nx.clustering(random_swap_model,weight="flow")

# %%
# # 提取聚类系数和度数
# G_total_degrees = [deg for node, deg in G_total.in_degree(weight="flow")]
# G_total_cl_values = list(G_total_cl.values())

# # config_degrees = [deg for node, deg in config_model.in_degree(weight="flow")]
# # config_cl_values = list(config_cl.values())

# random_swap_degrees = [deg for node, deg in random_swap_model.in_degree(weight="flow")]
# random_swap_cl_values = list(random_swap_cl.values())

# %%
# plt.style.available

# %%
# with plt.style.context("fivethirtyeight"), sns.plotting_context(context="poster",font_scale=0.5):
#     fig, ax = plt.subplots(figsize=(7, 5))
#     fig.patch.set_facecolor('white')
#     ax.set_facecolor('white')
#     for spine in ax.spines.values():
#         spine.set_edgecolor('white')

#     plt.scatter(G_total_degrees, G_total_cl_values, alpha=0.5, label='G_total')
#     # plt.scatter(config_degrees, config_cl_values, alpha=0.5, label='config_model')
#     plt.scatter(random_swap_degrees, random_swap_cl_values, alpha=0.5, label='random_swap_model')

#     plt.xlabel('Degree ($k$)')
#     plt.ylabel('Clustering Coefficient $C(k)$')
#     plt.title('Scatter plot of Clustering Coefficient vs Degree',fontsize = 20,weight = "bold")
#     plt.tight_layout()
#     plt.grid(False)
#     # plt.legend([f"Original network ($<C>$ = {G_total_avcl:2f})", f"Configuration model ($<C>$ = {config_avcl:2f})",f"Degree preserve random ($<C>$ = {config_avcl:2f})"],loc = "lower right",frameon = True)
#     plt.legend([f"Original network ($<C>$ = {G_total_avcl:2f})",f"Degree preserve random ($<C>$ = {random_swap_avcl:2f})"],loc = "lower right",frameon = True)
#     # plt.show()
#     plt.tight_layout()
#     plt.savefig("output/plot/Clustering Coefficient vs Degree.svg",bbox_inches="tight",transparent=True)
#     plt.savefig("output/plot/Clustering Coefficient vs Degree.pdf",bbox_inches="tight",transparent=True)

# %% [markdown]
# For 6 networks

# %%
# G_total_avcl = nx.average_clustering(G_total,weight="flow")
# G_earlymorning_avcl = nx.average_clustering(G_earlymorning,weight="flow")
# G_morningrush_avcl = nx.average_clustering(G_morningrush,weight="flow")
# G_morningtonoon_avcl = nx.average_clustering(G_morningtonoon,weight="flow")
# G_afternoon_avcl = nx.average_clustering(G_afternoon,weight="flow")
# G_eveningrush_avcl = nx.average_clustering(G_eveningrush,weight="flow")
# G_night_avcl = nx.average_clustering(G_night,weight="flow")

# %%
# print(
#     f"Average clustering coefficient of the total network: {G_total_avcl}\n"
#     f"Average clustering coefficient of the early morning network: {G_earlymorning_avcl}\n"
#     f"Average clustering coefficient of the morning rush network: {G_morningrush_avcl}\n"
#     f"Average clustering coefficient of the morning to noon network: {G_morningtonoon_avcl}\n"
#     f"Average clustering coefficient of the afternoon network: {G_afternoon_avcl}\n"
#     f"Average clustering coefficient of the evening rush network: {G_eveningrush_avcl}\n"
#     f"Average clustering coefficient of the night network: {G_night_avcl}"
# )

# %% [markdown]
# total network: 0.0008061805452651452
#
# early morning network: 0.0010453848604893763
#
# morning rush network: 0.001055425152028369
#
# morning to noon network: 0.0016668853807481519
#
# afternoon network: 0.001622218566868547
#
# evening rush network: 0.003917600375957059
#
# night network: 0.002646063046402736

# %% [markdown]
# ## Betweeen centrality

# %%
# G_total_bc = nx.betweenness_centrality(G_total,weight="flow")
# config_bc = nx.betweenness_centrality(config_model,weight="flow")
# random_swap_bc = nx.betweenness_centrality(random_swap_model,weight="flow")

# G_earlymorning_bc = nx.betweenness_centrality(G_total,weight="flow")
# G_morningrush_bc = nx.betweenness_centrality(G_morningrush_bc,weight="flow")
# G_morningtonoon_bc = nx.betweenness_centrality(G_morningtonoon_bc,weight="flow")
# G_afternoon_bc = nx.betweenness_centrality(G_afternoon_bc,weight="flow")
# G_eveningrush_bc = nx.betweenness_centrality(G_eveningrush_bc,weight="flow")
# G_night_bc = nx.betweenness_centrality(G_night_bc,weight="flow")

# %%
# G_total_bc_values = list(G_total_bc.values())
# config_bc_values = list(config_bc.values())
# random_swap_bc_values = list(random_swap_bc.values())

# %%
# nx.draw(G_total, node_size=[v * 1000 for v in G_total_bc_values])

# %% [markdown]
# # Community

# %%
def community_detection_with_algorithms(G):
    partition_louvain = nx.community.louvain_communities(G, seed=123)
    modularity_louvain = nx.community.quality.modularity(G, partition_louvain,weight = "flow")
    # print(f"Louvain Modularity: {modularity_louvain}")

    # Infomap
    infomap = Infomap(directed=True,num_trials= 15)
    # communities_infomap = 
    for e in G.edges(data=True):
        infomap.addLink(e[0], e[1], e[2]['flow'])
    infomap.run()

    # 去重处理
    communities_infomap = {}
    for node in infomap.iterTree():
        if node.isLeaf():
            module_id = node.module_id
            if module_id not in communities_infomap:
                communities_infomap[module_id] = []
            communities_infomap[module_id].append(node.node_id)
    partition_infomap = list(communities_infomap.values())
        
    # Calculate modularity for Infomap
    modularity_infomap = nx.community.quality.modularity(G, partition_infomap, weight='weight')
    # print(f"Infomap Modularity: {modularity_infomap}")

    return {
        'Louvain': partition_louvain,
        "Louvain_modularity":modularity_louvain,
        'Infomap': partition_infomap,
        "Infor_modularity":modularity_infomap
    }
    
def save_partiton_tograph(G, partition, partition_name):
    # Add community to node attributes
    for i, comm in enumerate(partition):
        for node in comm:
            G.nodes[node][partition_name] = i

# %%
def get_community_result(G):
    community_dict = community_detection_with_algorithms(G)
    # print(f"Number of communities detected by Louvain: {len(community_counts['Louvain'])}")
    # print(f"Number of communities detected by Infomap: {len(community_counts['Infomap'])}")
    save_partiton_tograph(G,community_dict["Louvain"],"Louvain_community")
    save_partiton_tograph(G,community_dict["Infomap"],"Infomap_community")
    return len(community_dict['Louvain']), len(community_dict['Infomap']), community_dict['Louvain_modularity'],community_dict["Infor_modularity"]

# %%
total_Lpartition_len, total_Ipartition_len, total_Lpartition_m, total_Ipartition_m = get_community_result(G_total)
earlymorning_Lpartition_len, earlymorning_Ipartition_len, earlymorning_Lpartition_m, earlymorning_Ipartition_m = get_community_result(G_earlymorning)
morningrush_Lpartition_len, morningrush_Ipartition_len, morningrush_Lpartition_m, morningrush_Ipartition_m = get_community_result(G_morningrush)
morningtonoon_Lpartition_len, morningtonoon_Ipartition_len, morningtonoon_Lpartition_m, morningtonoon_Ipartition_m = get_community_result(G_morningtonoon)
afternoon_Lpartition_len, afternoon_Ipartition_len, afternoon_Lpartition_m, afternoon_Ipartition_m = get_community_result(G_afternoon)
eveningrush_Lpartition_len, eveningrush_Ipartition_len, eveningrush_Lpartition_m, eveningrush_Ipartition_m = get_community_result(G_eveningrush)
night_Lpartition_len, night_Ipartition_len, night_Lpartition_m, night_Ipartition_m = get_community_result(G_night)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 total_Lpartition_len, total_Ipartition_len, total_Lpartition_m, total_Ipartition_m = get_community_result(G_total)
#       2 earlymorning_Lpartition_len, earlymorning_Ipartition_len, earlymorning_Lpartition_m, earlymorning_Ipartition_m = get_community_result(G_earlymorning)
#       3 morningrush_Lpartition_len, morningrush_Ipartition_len, morningrush_Lpartition_m, morningrush_Ipartition_m = get_community_result(G_morningrush)
#
# Cell In[34], line 2, in get_community_result(G)
#       1 def get_community_result(G):
# ----> 2     community_dict = community_detection_with_algorithms(G)
#       3     # print(f"Number of communities detected by Louvain: {len(community_counts['Louvain'])}")
#       4     # print(f"Number of communities detected by Infomap: {len(community_counts['Infomap'])}")
#       5     save_partiton_tograph(G,community_dict["Louvain"],"Louvain_community")
#
# Cell In[33], line 7, in community_detection_with_algorithms(G)
#       3 modularity_louvain = nx.community.quality.modularity(G, partition_louvain,weight = "flow")
#       4 # print(f"Louvain Modularity: {modularity_louvain}")
#       5
#       6 # Infomap
# ----> 7 infomap = Infomap(directed=True,num_trials= 15)
#       8 # communities_infomap =
#       9 for e in G.edges(data=True):
#
# NameError: name 'Infomap' is not defined

# %%
df_community = pd.DataFrame(
    {
        "Total": [total_Lpartition_len, total_Ipartition_len, total_Lpartition_m, total_Ipartition_m],
        "Early Morning": [earlymorning_Lpartition_len, earlymorning_Ipartition_len, earlymorning_Lpartition_m, earlymorning_Ipartition_m],
        "Morning Rush": [morningrush_Lpartition_len, morningrush_Ipartition_len, morningrush_Lpartition_m, morningrush_Ipartition_m],
        "Morning to Noon": [morningtonoon_Lpartition_len, morningtonoon_Ipartition_len, morningtonoon_Lpartition_m, morningtonoon_Ipartition_m],
        "Afternoon": [afternoon_Lpartition_len, afternoon_Ipartition_len, afternoon_Lpartition_m, afternoon_Ipartition_m],
        "Evening Rush": [eveningrush_Lpartition_len, eveningrush_Ipartition_len, eveningrush_Lpartition_m, eveningrush_Ipartition_m],
        "Night": [night_Lpartition_len, night_Ipartition_len, night_Lpartition_m, night_Ipartition_m]
    },
    index=["Louvain Community Count", "Infomap Community Count", "Louvain Modularity", "Infomap Modularity"]
)
df_community.to_csv("data/df_community.csv",index = True)

# %%
saveall_gexf()

# %% [markdown]
# ### save total partition to geo

# %%
G_total_community_dict = community_detection_with_algorithms(G_total)
G_earlymorning_community_dict = community_detection_with_algorithms(G_earlymorning)
G_morningrush_community_dict = community_detection_with_algorithms(G_morningrush)
G_morningtonoon_community_dict = community_detection_with_algorithms(G_morningtonoon)
G_afternoon_community_dict = community_detection_with_algorithms(G_afternoon)
G_eveningrush_community_dict = community_detection_with_algorithms(G_eveningrush)
G_night_community_dict = community_detection_with_algorithms(G_night)
# Out:
# =======================================================
#   Infomap v2.7.1 starts at 2024-06-01 21:36:57
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
#                     num-trials = 15
# =======================================================
#   OpenMP 201511 detected with 16 threads...
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1.000000000, sum link flow: 1.000000000
# Build internal network with 260 nodes and 25971 links...
#   -> One-level codelength: 6.094875347
#
# ================================================
# Trial 1/15 starting at 2024-06-01 21:36:57
# ================================================
# Two-level compression: 1.57% 0.02%
# Partitioned to codelength 0.111400531 + 5.886977713 = 5.998378245 in 6 modules.
# Super-level compression: to codelength 5.998378245 in 6 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.998378245
#
# => Trial 1/15 finished in 0.025143931s with codelength 5.998378245
#
# ================================================
# Trial 2/15 starting at 2024-06-01 21:36:57
# ================================================
# Two-level compression: 1.51% 0.33%
# Partitioned to codelength 0.138624266 + 5.844661581 = 5.983285846 in 8 modules.
# Super-level compression: to codelength 5.983285846 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.983285846
#
# => Trial 2/15 finished in 0.033609176s with codelength 5.983285846
#
# ================================================
# Trial 3/15 starting at 2024-06-01 21:36:57
# ================================================
# Two-level compression: 1.52% 0.30%
# Partitioned to codelength 0.138664629 + 5.845337951 = 5.984002581 in 6 modules.
# Super-level compression: to codelength 5.984002581 in 6 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.984002581
#
# => Trial 3/15 finished in 0.025905036s with codelength 5.984002581
#
# ================================================
# Trial 4/15 starting at 2024-06-01 21:36:57
# ================================================
# Two-level compression: 1.59% 0.25%
# Partitioned to codelength 0.138400689 + 5.844913587 = 5.983314276 in 7 modules.
# Super-level compression: to codelength 5.983314276 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.983314276
#
# => Trial 4/15 finished in 0.020232606s with codelength 5.983314276
#
# ================================================
# Trial 5/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.21% 0.33%
# Partitioned to codelength 0.088047855 + 5.913062460 = 6.001110315 in 5 modules.
# Super-level compression: to codelength 6.001110315 in 5 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.001110315
#
# => Trial 5/15 finished in 0.026556239s with codelength 6.001110315
#
# ================================================
# Trial 6/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.52% 0.32%
# Partitioned to codelength 0.138400689 + 5.844913587 = 5.983314276 in 7 modules.
# Super-level compression: to codelength 5.983314276 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.983314276
#
# => Trial 6/15 finished in 0.022430917s with codelength 5.983314276
#
# ================================================
# Trial 7/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.54% 0.29%
# Partitioned to codelength 0.138261099 + 5.845187250 = 5.983448348 in 8 modules.
# Super-level compression: to codelength 5.983448348 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.983448348
#
# => Trial 7/15 finished in 0.017762993s with codelength 5.983448348
#
# ================================================
# Trial 8/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.60% 0.22%
# Partitioned to codelength 0.136866947 + 5.847392942 = 5.984259888 in 6 modules.
# Super-level compression: to codelength 5.984259888 in 6 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.984259888
#
# => Trial 8/15 finished in 0.022249817s with codelength 5.984259888
#
# ================================================
# Trial 9/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.65% 0.18%
# Partitioned to codelength 0.138560085 + 5.844729583 = 5.983289668 in 7 modules.
# Super-level compression: to codelength 5.983289668 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.983289668
#
# => Trial 9/15 finished in 0.017928693s with codelength 5.983289668
#
# ================================================
# Trial 10/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.42% 0.41%
# Partitioned to codelength 0.138560085 + 5.844729583 = 5.983289668 in 7 modules.
# Super-level compression: to codelength 5.983289668 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.983289668
#
# => Trial 10/15 finished in 0.019170000s with codelength 5.983289668
#
# ================================================
# Trial 11/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.69% 0.09%
# Partitioned to codelength 0.113282152 + 5.873173093 = 5.986455245 in 6 modules.
# Super-level compression: to codelength 5.986455245 in 6 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.986455245
#
# => Trial 11/15 finished in 0.019465302s with codelength 5.986455245
#
# ================================================
# Trial 12/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.62% 0.21%
# Partitioned to codelength 0.138560085 + 5.844729583 = 5.983289668 in 7 modules.
# Super-level compression: to codelength 5.983289668 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.983289668
#
# => Trial 12/15 finished in 0.018985899s with codelength 5.983289668
#
# ================================================
# Trial 13/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.62% 0.18%
# Partitioned to codelength 0.114740951 + 5.870757671 = 5.985498622 in 6 modules.
# Super-level compression: to codelength 5.985498622 in 6 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.985498622
#
# => Trial 13/15 finished in 0.026835840s with codelength 5.985498622
#
# ================================================
# Trial 14/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.58% 0.26%
# Partitioned to codelength 0.138577734 + 5.844711082 = 5.983288815 in 8 modules.
# Super-level compression: to codelength 5.983288815 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.983288815
#
# => Trial 14/15 finished in 0.018811898s with codelength 5.983288815
#
# ================================================
# Trial 15/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.66% 0.17%
# Partitioned to codelength 0.138560085 + 5.844729583 = 5.983289668 in 7 modules.
# Super-level compression: to codelength 5.983289668 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.983289668
#
# => Trial 15/15 finished in 0.022012015s with codelength 5.983289668
#
#
# ================================================
# Summary after 15 trials
# ================================================
#
#  -> Initiated to codelength 5.983285846 in 2 levels with 8 top modules.
# Codelengths: [5.998378245, 5.983285846, 5.984002581, 5.983314276, 6.001110315, 5.983314276, 5.983448348, 5.984259888, 5.983289668, 5.983289668, 5.986455245, 5.983289668, 5.985498622, 5.983288815, 5.983289668]
# [min, average, max] codelength: [5.983285846, 5.985967675, 6.001110315]
#
# Best end modular solution in 2 levels:
# Per level number of modules:         [          8,           0] (sum: 8)
# Per level number of leaf nodes:      [          0,         260] (sum: 260)
# Per level average child degree:      [          8,        32.5] (average: 31.768656716)
# Per level codelength for modules:    [0.138624266, 0.000000000] (sum: 0.138624266)
# Per level codelength for leaf nodes: [0.000000000, 5.844661581] (sum: 5.844661581)
# Per level codelength total:          [0.138624266, 5.844661581] (sum: 5.983285846)
#
# ===================================================
#   Infomap ends at 2024-06-01 21:36:58
#   (Elapsed time: 0.365109409s)
# ===================================================
# =======================================================
#   Infomap v2.7.1 starts at 2024-06-01 21:36:58
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
#                     num-trials = 15
# =======================================================
#   OpenMP 201511 detected with 16 threads...
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1.000000000, sum link flow: 1.000000000
# Build internal network with 255 nodes and 17371 links...
#   -> One-level codelength: 5.908786551
#
# ================================================
# Trial 1/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.12% 0.29%
# Partitioned to codelength 0.109396761 + 5.716147071 = 5.825543832 in 8 (7 non-trivial) modules.
# Super-level compression: to codelength 5.825543832 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.825543832
#
# => Trial 1/15 finished in 0.020679203s with codelength 5.825543832
#
# ================================================
# Trial 2/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.08% 0.39%
# Partitioned to codelength 0.093242899 + 5.729026520 = 5.822269419 in 7 (6 non-trivial) modules.
# Super-level compression: to codelength 5.822269419 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.822269419
#
# => Trial 2/15 finished in 0.016709283s with codelength 5.822269419
#
# ================================================
# Trial 3/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.02% 0.50%
# Partitioned to codelength 0.121457316 + 5.697576898 = 5.819034214 in 8 (7 non-trivial) modules.
# Super-level compression: to codelength 5.819034214 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.819034214
#
# => Trial 3/15 finished in 0.016897583s with codelength 5.819034214
#
# ================================================
# Trial 4/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.10% 0.20%
# Partitioned to codelength 0.079852419 + 5.752098777 = 5.831951196 in 7 (6 non-trivial) modules.
# Super-level compression: to codelength 5.831951196 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.831951196
#
# => Trial 4/15 finished in 0.020068899s with codelength 5.831951196
#
# ================================================
# Trial 5/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.33% 0.19%
# Partitioned to codelength 0.117662358 + 5.701343943 = 5.819006301 in 8 (7 non-trivial) modules.
# Super-level compression: to codelength 5.819006301 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.819006301
#
# => Trial 5/15 finished in 0.018296991s with codelength 5.819006301
#
# ================================================
# Trial 6/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 0.82% 0.60%
# Partitioned to codelength 0.106535807 + 5.718782113 = 5.82531792 in 8 (7 non-trivial) modules.
# Super-level compression: to codelength 5.82531792 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.82531792
#
# => Trial 6/15 finished in 0.020477301s with codelength 5.825317920
#
# ================================================
# Trial 7/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 0.91% 0.58%
# Partitioned to codelength 0.105882525 + 5.715585646 = 5.821468171 in 8 (7 non-trivial) modules.
# Super-level compression: to codelength 5.821468171 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.821468171
#
# => Trial 7/15 finished in 0.020110699s with codelength 5.821468171
#
# ================================================
# Trial 8/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 0.94% 0.36%
# Partitioned to codelength 0.093738597 + 5.737937131 = 5.831675728 in 7 (6 non-trivial) modules.
# Super-level compression: to codelength 5.831675728 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.831675728
#
# => Trial 8/15 finished in 0.021444707s with codelength 5.831675728
#
# ================================================
# Trial 9/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 0.97% 0.44%
# Partitioned to codelength 0.087721628 + 5.737823730 = 5.825545357 in 7 (6 non-trivial) modules.
# Super-level compression: to codelength 5.825545357 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.825545357
#
# => Trial 9/15 finished in 0.017163985s with codelength 5.825545357
#
# ================================================
# Trial 10/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.15% 0.39%
# Partitioned to codelength 0.128924456 + 5.689544841 = 5.818469297 in 9 (8 non-trivial) modules.
# Super-level compression: to codelength 5.818469297 in 9 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.818469297
#
# => Trial 10/15 finished in 0.015166575s with codelength 5.818469297
#
# ================================================
# Trial 11/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 0.84% 0.57%
# Partitioned to codelength 0.087721628 + 5.737823730 = 5.825545357 in 7 (6 non-trivial) modules.
# Super-level compression: to codelength 5.825545357 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.825545357
#
# => Trial 11/15 finished in 0.024815023s with codelength 5.825545357
#
# ================================================
# Trial 12/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 1.08% 0.44%
# Partitioned to codelength 0.121457316 + 5.697576898 = 5.819034214 in 8 (7 non-trivial) modules.
# Super-level compression: to codelength 5.819034214 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.819034214
#
# => Trial 12/15 finished in 0.019964699s with codelength 5.819034214
#
# ================================================
# Trial 13/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 0.66% 0.52%
# Partitioned to codelength 0.055803333 + 5.783823328 = 5.839626661 in 6 (5 non-trivial) modules.
# Super-level compression: to codelength 5.839626661 in 6 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.839626661
#
# => Trial 13/15 finished in 0.021916709s with codelength 5.839626661
#
# ================================================
# Trial 14/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 0.80% 0.37%
# Partitioned to codelength 0.092768681 + 5.746638041 = 5.839406722 in 8 (7 non-trivial) modules.
# Super-level compression: to codelength 5.839406722 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.839406722
#
# => Trial 14/15 finished in 0.023103414s with codelength 5.839406722
#
# ================================================
# Trial 15/15 starting at 2024-06-01 21:36:58
# ================================================
# Two-level compression: 0.50% 0.83%
# Partitioned to codelength 0.080049289 + 5.750427280 = 5.830476569 in 7 (6 non-trivial) modules.
# Super-level compression: to codelength 5.830476569 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.830476569
#
# => Trial 15/15 finished in 0.023576417s with codelength 5.830476569
#
#
# ================================================
# Summary after 15 trials
# ================================================
#
#  -> Initiated to codelength 5.818469297 in 2 levels with 9 top modules.
# Codelengths: [5.825543832, 5.822269419, 5.819034214, 5.831951196, 5.819006301, 5.825317920, 5.821468171, 5.831675728, 5.825545357, 5.818469297, 5.825545357, 5.819034214, 5.839626661, 5.839406722, 5.830476569]
# [min, average, max] codelength: [5.818469297, 5.826291397, 5.839626661]
#
# Best end modular solution in 2 levels:
# Per level number of modules:         [          9,           0] (sum: 9)
# Per level number of leaf nodes:      [          0,         255] (sum: 255)
# Per level average child degree:      [          9,     28.3333] (average: 27.674242424)
# Per level codelength for modules:    [0.128924456, 0.000000000] (sum: 0.128924456)
# Per level codelength for leaf nodes: [0.000000000, 5.689544841] (sum: 5.689544841)
# Per level codelength total:          [0.128924456, 5.689544841] (sum: 5.818469297)
#
# ===================================================
#   Infomap ends at 2024-06-01 21:36:58
#   (Elapsed time: 0.321216391s)
# ===================================================
# =======================================================
#   Infomap v2.7.1 starts at 2024-06-01 21:36:59
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
#                     num-trials = 15
# =======================================================
#   OpenMP 201511 detected with 16 threads...
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1.000000000, sum link flow: 1.000000000
# Build internal network with 256 nodes and 14079 links...
#   -> One-level codelength: 5.913601054
#
# ================================================
# Trial 1/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.77% 0.11%
# Partitioned to codelength 0.112010700 + 5.690118015 = 5.802128715 in 11 (9 non-trivial) modules.
# Super-level compression: to codelength 5.802128715 in 11 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.802128715
#
# => Trial 1/15 finished in 0.013169965s with codelength 5.802128715
#
# ================================================
# Trial 2/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.51% 0.36%
# Partitioned to codelength 0.093996190 + 5.709534587 = 5.803530777 in 10 (8 non-trivial) modules.
# Super-level compression: to codelength 5.803530777 in 10 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.803530777
#
# => Trial 2/15 finished in 0.020179600s with codelength 5.803530777
#
# ================================================
# Trial 3/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.76% 0.10%
# Partitioned to codelength 0.093996190 + 5.709534587 = 5.803530777 in 10 (8 non-trivial) modules.
# Super-level compression: to codelength 5.803530777 in 10 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.803530777
#
# => Trial 3/15 finished in 0.013586368s with codelength 5.803530777
#
# ================================================
# Trial 4/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.79% 0.10%
# Partitioned to codelength 0.112010700 + 5.690118015 = 5.802128715 in 11 (9 non-trivial) modules.
# Super-level compression: to codelength 5.802128715 in 11 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.802128715
#
# => Trial 4/15 finished in 0.019638697s with codelength 5.802128715
#
# ================================================
# Trial 5/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.64% 0.22%
# Partitioned to codelength 0.095722757 + 5.707881487 = 5.803604244 in 10 (8 non-trivial) modules.
# Super-level compression: to codelength 5.803604244 in 10 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.803604244
#
# => Trial 5/15 finished in 0.015693278s with codelength 5.803604244
#
# ================================================
# Trial 6/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.71% 0.17%
# Partitioned to codelength 0.106194589 + 5.696217615 = 5.802412204 in 11 (9 non-trivial) modules.
# Super-level compression: to codelength 5.802412204 in 11 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.802412204
#
# => Trial 6/15 finished in 0.020631002s with codelength 5.802412204
#
# ================================================
# Trial 7/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.61% 0.28%
# Partitioned to codelength 0.112010700 + 5.690118015 = 5.802128715 in 11 (9 non-trivial) modules.
# Super-level compression: to codelength 5.802128715 in 11 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.802128715
#
# => Trial 7/15 finished in 0.018756793s with codelength 5.802128715
#
# ================================================
# Trial 8/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.65% 0.21%
# Partitioned to codelength 0.093982825 + 5.709549220 = 5.803532046 in 9 (7 non-trivial) modules.
# Super-level compression: to codelength 5.803532046 in 9 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.803532046
#
# => Trial 8/15 finished in 0.021035804s with codelength 5.803532046
#
# ================================================
# Trial 9/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.58% 0.31%
# Partitioned to codelength 0.111997279 + 5.690132648 = 5.802129927 in 10 (8 non-trivial) modules.
# Super-level compression: to codelength 5.802129927 in 10 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.802129927
#
# => Trial 9/15 finished in 0.022998714s with codelength 5.802129927
#
# ================================================
# Trial 10/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.18% 0.54%
# Partitioned to codelength 0.075663008 + 5.736597533 = 5.81226054 in 8 (6 non-trivial) modules.
# Super-level compression: to codelength 5.81226054 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.81226054
#
# => Trial 10/15 finished in 0.018737293s with codelength 5.812260540
#
# ================================================
# Trial 11/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.67% 0.21%
# Partitioned to codelength 0.106194589 + 5.696217615 = 5.802412204 in 11 (9 non-trivial) modules.
# Super-level compression: to codelength 5.802412204 in 11 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.802412204
#
# => Trial 11/15 finished in 0.014553072s with codelength 5.802412204
#
# ================================================
# Trial 12/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.70% 0.17%
# Partitioned to codelength 0.114157483 + 5.688806409 = 5.802963892 in 11 (9 non-trivial) modules.
# Super-level compression: to codelength 5.802963892 in 11 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.802963892
#
# => Trial 12/15 finished in 0.017157485s with codelength 5.802963892
#
# ================================================
# Trial 13/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.77% 0.12%
# Partitioned to codelength 0.111997279 + 5.690132648 = 5.802129927 in 10 (8 non-trivial) modules.
# Super-level compression: to codelength 5.802129927 in 10 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.802129927
#
# => Trial 13/15 finished in 0.016305081s with codelength 5.802129927
#
# ================================================
# Trial 14/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.59% 0.06%
# Partitioned to codelength 0.074652600 + 5.741564030 = 5.81621663 in 9 (7 non-trivial) modules.
# Super-level compression: to codelength 5.81621663 in 9 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.81621663
#
# => Trial 14/15 finished in 0.019363596s with codelength 5.816216630
#
# ================================================
# Trial 15/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.80% 0.08%
# Partitioned to codelength 0.112010700 + 5.690118015 = 5.802128715 in 11 (9 non-trivial) modules.
# Super-level compression: to codelength 5.802128715 in 11 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.802128715
#
# => Trial 15/15 finished in 0.012963765s with codelength 5.802128715
#
#
# ================================================
# Summary after 15 trials
# ================================================
#
#  -> Initiated to codelength 5.802128715 in 2 levels with 11 top modules.
# Codelengths: [5.802128715, 5.803530777, 5.803530777, 5.802128715, 5.803604244, 5.802412204, 5.802128715, 5.803532046, 5.802129927, 5.812260540, 5.802412204, 5.802963892, 5.802129927, 5.816216630, 5.802128715]
# [min, average, max] codelength: [5.802128715, 5.804215869, 5.816216630]
#
# Best end modular solution in 2 levels:
# Per level number of modules:         [         11,           0] (sum: 11)
# Per level number of leaf nodes:      [          0,         256] (sum: 256)
# Per level average child degree:      [         11,     23.2727] (average: 22.7671)
# Per level codelength for modules:    [0.112010700, 0.000000000] (sum: 0.112010700)
# Per level codelength for leaf nodes: [0.000000000, 5.690118015] (sum: 5.690118015)
# Per level codelength total:          [0.112010700, 5.690118015] (sum: 5.802128715)
#
# ===================================================
#   Infomap ends at 2024-06-01 21:36:59
#   (Elapsed time: 0.278909482s)
# ===================================================
# =======================================================
#   Infomap v2.7.1 starts at 2024-06-01 21:36:59
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
#                     num-trials = 15
# =======================================================
#   OpenMP 201511 detected with 16 threads...
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1.000000000, sum link flow: 1.000000000
# Build internal network with 251 nodes and 9748 links...
#   -> One-level codelength: 5.884692235
#
# ================================================
# Trial 1/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.91% 0.09%
# Partitioned to codelength 0.095312824 + 5.671398693 = 5.766711517 in 8 modules.
# Super-level compression: to codelength 5.766711517 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.766711517
#
# => Trial 1/15 finished in 0.013153165s with codelength 5.766711517
#
# ================================================
# Trial 2/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.86% 0.11%
# Partitioned to codelength 0.078383133 + 5.690274908 = 5.768658042 in 7 modules.
# Super-level compression: to codelength 5.768658042 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.768658042
#
# => Trial 2/15 finished in 0.012114660s with codelength 5.768658042
#
# ================================================
# Trial 3/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.77% 0.20%
# Partitioned to codelength 0.078602646 + 5.689991846 = 5.768594492 in 7 modules.
# Super-level compression: to codelength 5.768594492 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.768594492
#
# => Trial 3/15 finished in 0.014328271s with codelength 5.768594492
#
# ================================================
# Trial 4/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.88% 0.13%
# Partitioned to codelength 0.095233181 + 5.671389778 = 5.766622959 in 8 modules.
# Super-level compression: to codelength 5.766622959 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.766622959
#
# => Trial 4/15 finished in 0.013640468s with codelength 5.766622959
#
# ================================================
# Trial 5/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.76% 0.20%
# Partitioned to codelength 0.088603754 + 5.680457705 = 5.76906146 in 8 modules.
# Super-level compression: to codelength 5.76906146 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.76906146
#
# => Trial 5/15 finished in 0.014103870s with codelength 5.769061460
#
# ================================================
# Trial 6/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.87% 0.14%
# Partitioned to codelength 0.095799560 + 5.670780448 = 5.766580007 in 10 modules.
# Super-level compression: to codelength 5.766580007 in 10 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.766580007
#
# => Trial 6/15 finished in 0.017172485s with codelength 5.766580007
#
# ================================================
# Trial 7/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.45% 0.24%
# Partitioned to codelength 0.075435282 + 5.709774634 = 5.785209916 in 7 modules.
# Super-level compression: to codelength 5.785209916 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.785209916
#
# => Trial 7/15 finished in 0.020023299s with codelength 5.785209916
#
# ================================================
# Trial 8/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.87% 0.14%
# Partitioned to codelength 0.095233181 + 5.671389778 = 5.766622959 in 8 modules.
# Super-level compression: to codelength 5.766622959 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.766622959
#
# => Trial 8/15 finished in 0.012853464s with codelength 5.766622959
#
# ================================================
# Trial 9/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.84% 0.14%
# Partitioned to codelength 0.078382897 + 5.690275158 = 5.768658055 in 7 modules.
# Super-level compression: to codelength 5.768658055 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.768658055
#
# => Trial 9/15 finished in 0.012902564s with codelength 5.768658055
#
# ================================================
# Trial 10/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.84% 0.13%
# Partitioned to codelength 0.078602646 + 5.689991846 = 5.768594492 in 7 modules.
# Super-level compression: to codelength 5.768594492 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.768594492
#
# => Trial 10/15 finished in 0.013303966s with codelength 5.768594492
#
# ================================================
# Trial 11/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.65% 0.32%
# Partitioned to codelength 0.078382897 + 5.690275158 = 5.768658055 in 7 modules.
# Super-level compression: to codelength 5.768658055 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.768658055
#
# => Trial 11/15 finished in 0.016441282s with codelength 5.768658055
#
# ================================================
# Trial 12/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.83% 0.16%
# Partitioned to codelength 0.093406393 + 5.674194725 = 5.767601118 in 8 modules.
# Super-level compression: to codelength 5.767601118 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.767601118
#
# => Trial 12/15 finished in 0.014484271s with codelength 5.767601118
#
# ================================================
# Trial 13/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.83% 0.17%
# Partitioned to codelength 0.093971782 + 5.673585388 = 5.76755717 in 10 modules.
# Super-level compression: to codelength 5.76755717 in 10 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.76755717
#
# => Trial 13/15 finished in 0.012811063s with codelength 5.767557170
#
# ================================================
# Trial 14/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.63% 0.36%
# Partitioned to codelength 0.093406393 + 5.674194725 = 5.767601118 in 8 modules.
# Super-level compression: to codelength 5.767601118 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.767601118
#
# => Trial 14/15 finished in 0.011417057s with codelength 5.767601118
#
# ================================================
# Trial 15/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 1.81% 0.20%
# Partitioned to codelength 0.095233181 + 5.671389778 = 5.766622959 in 8 modules.
# Super-level compression: to codelength 5.766622959 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.766622959
#
# => Trial 15/15 finished in 0.012638362s with codelength 5.766622959
#
#
# ================================================
# Summary after 15 trials
# ================================================
#
#  -> Initiated to codelength 5.766580007 in 2 levels with 10 top modules.
# Codelengths: [5.766711517, 5.768658042, 5.768594492, 5.766622959, 5.769061460, 5.766580007, 5.785209916, 5.766622959, 5.768658055, 5.768594492, 5.768658055, 5.767601118, 5.767557170, 5.767601118, 5.766622959]
# [min, average, max] codelength: [5.766580007, 5.768890288, 5.785209916]
#
# Best end modular solution in 2 levels:
# Per level number of modules:         [         10,           0] (sum: 10)
# Per level number of leaf nodes:      [          0,         251] (sum: 251)
# Per level average child degree:      [         10,        25.1] (average: 24.521455939)
# Per level codelength for modules:    [0.095799560, 0.000000000] (sum: 0.095799560)
# Per level codelength for leaf nodes: [0.000000000, 5.670780448] (sum: 5.670780448)
# Per level codelength total:          [0.095799560, 5.670780448] (sum: 5.766580007)
#
# ===================================================
#   Infomap ends at 2024-06-01 21:36:59
#   (Elapsed time: 0.222067600s)
# ===================================================
# =======================================================
#   Infomap v2.7.1 starts at 2024-06-01 21:36:59
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
#                     num-trials = 15
# =======================================================
#   OpenMP 201511 detected with 16 threads...
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1.000000000, sum link flow: 1.000000000
# Build internal network with 256 nodes and 13978 links...
#   -> One-level codelength: 6.073893126
#
# ================================================
# Trial 1/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 2.13% 0.10%
# Partitioned to codelength 0.134347594 + 5.804395273 = 5.938742867 in 9 (8 non-trivial) modules.
# Super-level compression: to codelength 5.938742867 in 9 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.938742867
#
# => Trial 1/15 finished in 0.016098280s with codelength 5.938742867
#
# ================================================
# Trial 2/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 2.19% 0.05%
# Partitioned to codelength 0.147171788 + 5.790556231 = 5.937728019 in 10 (9 non-trivial) modules.
# Super-level compression: to codelength 5.937728019 in 10 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.937728019
#
# => Trial 2/15 finished in 0.013522067s with codelength 5.937728019
#
# ================================================
# Trial 3/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 2.07% 0.16%
# Partitioned to codelength 0.136560424 + 5.801791757 = 5.938352181 in 10 (9 non-trivial) modules.
# Super-level compression: to codelength 5.938352181 in 10 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.938352181
#
# => Trial 3/15 finished in 0.016759383s with codelength 5.938352181
#
# ================================================
# Trial 4/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 2.11% 0.12%
# Partitioned to codelength 0.136560424 + 5.801791757 = 5.938352181 in 10 (9 non-trivial) modules.
# Super-level compression: to codelength 5.938352181 in 10 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.938352181
#
# => Trial 4/15 finished in 0.014470271s with codelength 5.938352181
#
# ================================================
# Trial 5/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 2.04% 0.19%
# Partitioned to codelength 0.115757655 + 5.823413542 = 5.939171196 in 9 (8 non-trivial) modules.
# Super-level compression: to codelength 5.939171196 in 9 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.939171196
#
# => Trial 5/15 finished in 0.015387476s with codelength 5.939171196
#
# ================================================
# Trial 6/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 2.13% 0.09%
# Partitioned to codelength 0.115757655 + 5.823413542 = 5.939171196 in 9 (8 non-trivial) modules.
# Super-level compression: to codelength 5.939171196 in 9 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.939171196
#
# => Trial 6/15 finished in 0.017207385s with codelength 5.939171196
#
# ================================================
# Trial 7/15 starting at 2024-06-01 21:36:59
# ================================================
# Two-level compression: 2.14% 0.09%
# Partitioned to codelength 0.145134112 + 5.792944053 = 5.938078165 in 9 (8 non-trivial) modules.
# Super-level compression: to codelength 5.938078165 in 9 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.938078165
#
# => Trial 7/15 finished in 0.016830084s with codelength 5.938078165
#
# ================================================
# Trial 8/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.08% 0.14%
# Partitioned to codelength 0.115757655 + 5.823413542 = 5.939171196 in 9 (8 non-trivial) modules.
# Super-level compression: to codelength 5.939171196 in 9 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.939171196
#
# => Trial 8/15 finished in 0.021297505s with codelength 5.939171196
#
# ================================================
# Trial 9/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.14% 0.09%
# Partitioned to codelength 0.136560424 + 5.801791757 = 5.938352181 in 10 (9 non-trivial) modules.
# Super-level compression: to codelength 5.938352181 in 10 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.938352181
#
# => Trial 9/15 finished in 0.015736278s with codelength 5.938352181
#
# ================================================
# Trial 10/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.13% 0.09%
# Partitioned to codelength 0.115757655 + 5.823413542 = 5.939171196 in 9 (8 non-trivial) modules.
# Super-level compression: to codelength 5.939171196 in 9 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.939171196
#
# => Trial 10/15 finished in 0.013709068s with codelength 5.939171196
#
# ================================================
# Trial 11/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 1.57% 0.33%
# Partitioned to codelength 0.110323968 + 5.848707580 = 5.959031549 in 8 (7 non-trivial) modules.
# Super-level compression: to codelength 5.959031549 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.959031549
#
# => Trial 11/15 finished in 0.018398591s with codelength 5.959031549
#
# ================================================
# Trial 12/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.02% 0.22%
# Partitioned to codelength 0.126213088 + 5.812171999 = 5.938385087 in 9 (8 non-trivial) modules.
# Super-level compression: to codelength 5.938385087 in 9 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.938385087
#
# => Trial 12/15 finished in 0.014362671s with codelength 5.938385087
#
# ================================================
# Trial 13/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.01% 0.18%
# Partitioned to codelength 0.127200914 + 5.813516611 = 5.940717525 in 9 (8 non-trivial) modules.
# Super-level compression: to codelength 5.940717525 in 9 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.940717525
#
# => Trial 13/15 finished in 0.018373991s with codelength 5.940717525
#
# ================================================
# Trial 14/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 1.84% 0.01%
# Partitioned to codelength 0.099470006 + 5.861831099 = 5.961301105 in 8 (7 non-trivial) modules.
# Super-level compression: to codelength 5.961301105 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.961301105
#
# => Trial 14/15 finished in 0.018257590s with codelength 5.961301105
#
# ================================================
# Trial 15/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.11% 0.12%
# Partitioned to codelength 0.134531608 + 5.804179766 = 5.938711374 in 9 (8 non-trivial) modules.
# Super-level compression: to codelength 5.938711374 in 9 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 5.938711374
#
# => Trial 15/15 finished in 0.014503472s with codelength 5.938711374
#
#
# ================================================
# Summary after 15 trials
# ================================================
#
#  -> Initiated to codelength 5.937728019 in 2 levels with 10 top modules.
# Codelengths: [5.938742867, 5.937728019, 5.938352181, 5.938352181, 5.939171196, 5.939171196, 5.938078165, 5.939171196, 5.938352181, 5.939171196, 5.959031549, 5.938385087, 5.940717525, 5.961301105, 5.938711374]
# [min, average, max] codelength: [5.937728019, 5.941629135, 5.961301105]
#
# Best end modular solution in 2 levels:
# Per level number of modules:         [         10,           0] (sum: 10)
# Per level number of leaf nodes:      [          0,         256] (sum: 256)
# Per level average child degree:      [         10,        25.6] (average: 25.013533835)
# Per level codelength for modules:    [0.147171788, 0.000000000] (sum: 0.147171788)
# Per level codelength for leaf nodes: [0.000000000, 5.790556231] (sum: 5.790556231)
# Per level codelength total:          [0.147171788, 5.790556231] (sum: 5.937728019)
#
# ===================================================
#   Infomap ends at 2024-06-01 21:37:00
#   (Elapsed time: 0.258731482s)
# ===================================================
# =======================================================
#   Infomap v2.7.1 starts at 2024-06-01 21:37:00
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
#                     num-trials = 15
# =======================================================
#   OpenMP 201511 detected with 16 threads...
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1.000000000, sum link flow: 1.000000000
# Build internal network with 256 nodes and 13322 links...
#   -> One-level codelength: 6.424435720
#
# ================================================
# Trial 1/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.64% 0.11%
# ...
# Two-level compression: 2.63% 0.12%
# Partitioned to codelength 0.198279807 + 6.049301587 = 6.247581394 in 6 modules.
# Super-level compression: to codelength 6.247581394 in 6 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.247581394
#
# => Trial 5/15 finished in 0.016110380s with codelength 6.247581394
#
# ================================================
# Trial 6/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.51% 0.25%
# Partitioned to codelength 0.198154120 + 6.049500407 = 6.247654527 in 6 modules.
# Super-level compression: to codelength 6.247654527 in 6 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.247654527
#
# => Trial 6/15 finished in 0.018559292s with codelength 6.247654527
#
# ================================================
# Trial 7/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.57% 0.23%
# Partitioned to codelength 0.224348955 + 6.020499646 = 6.244848601 in 7 modules.
# Super-level compression: to codelength 6.244848601 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.244848601
#
# => Trial 7/15 finished in 0.015214075s with codelength 6.244848601
#
# ================================================
# Trial 8/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.60% 0.20%
# Partitioned to codelength 0.226642070 + 6.018199245 = 6.244841315 in 7 modules.
# Super-level compression: to codelength 6.244841315 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.244841315
#
# => Trial 8/15 finished in 0.015490376s with codelength 6.244841315
#
# ================================================
# Trial 9/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.66% 0.08%
# Partitioned to codelength 0.195004383 + 6.053917651 = 6.248922034 in 5 modules.
# Super-level compression: to codelength 6.248922034 in 5 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.248922034
#
# => Trial 9/15 finished in 0.013501467s with codelength 6.248922034
#
# ================================================
# Trial 10/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.72% 0.06%
# Partitioned to codelength 0.225991596 + 6.019552509 = 6.245544105 in 6 modules.
# Super-level compression: to codelength 6.245544105 in 6 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.245544105
#
# => Trial 10/15 finished in 0.016466982s with codelength 6.245544105
#
# ================================================
# Trial 11/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.55% 0.25%
# Partitioned to codelength 0.228402846 + 6.016569564 = 6.24497241 in 7 modules.
# Super-level compression: to codelength 6.24497241 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.24497241
#
# => Trial 11/15 finished in 0.016368681s with codelength 6.244972410
#
# ================================================
# Trial 12/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.14% 0.67%
# Partitioned to codelength 0.224348955 + 6.020499646 = 6.244848601 in 7 modules.
# Super-level compression: to codelength 6.244848601 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.244848601
#
# => Trial 12/15 finished in 0.013051665s with codelength 6.244848601
#
# ================================================
# Trial 13/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.51% 0.29%
# Partitioned to codelength 0.224348955 + 6.020499646 = 6.244848601 in 7 modules.
# Super-level compression: to codelength 6.244848601 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.244848601
#
# => Trial 13/15 finished in 0.013789168s with codelength 6.244848601
#
# ================================================
# Trial 14/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.52% 0.29%
# Partitioned to codelength 0.224453310 + 6.020358027 = 6.244811337 in 7 modules.
# Super-level compression: to codelength 6.244811337 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.244811337
#
# => Trial 14/15 finished in 0.012520362s with codelength 6.244811337
#
# ================================================
# Trial 15/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.01% 0.15%
# Partitioned to codelength 0.176457631 + 6.109159413 = 6.285617044 in 6 (5 non-trivial) modules.
# Super-level compression: to codelength 6.285617044 in 6 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.285617044
#
# => Trial 15/15 finished in 0.020291001s with codelength 6.285617044
#
#
# ================================================
# Summary after 15 trials
# ================================================
#
#  -> Initiated to codelength 6.244811337 in 2 levels with 7 top modules.
# Codelengths: [6.247581394, 6.248208698, 6.285137322, 6.245437546, 6.247581394, 6.247654527, 6.244848601, 6.244841315, 6.248922034, 6.245544105, 6.244972410, 6.244848601, 6.244848601, 6.244811337, 6.285617044]
# [min, average, max] codelength: [6.244811337, 6.251390329, 6.285617044]
#
# Best end modular solution in 2 levels:
# Per level number of modules:         [          7,           0] (sum: 7)
# Per level number of leaf nodes:      [          0,         256] (sum: 256)
# Per level average child degree:      [          7,     36.5714] (average: 35.784356328)
# Per level codelength for modules:    [0.224453310, 0.000000000] (sum: 0.224453310)
# Per level codelength for leaf nodes: [0.000000000, 6.020358027] (sum: 6.020358027)
# Per level codelength total:          [0.224453310, 6.020358027] (sum: 6.244811337)
#
# ===================================================
#   Infomap ends at 2024-06-01 21:37:00
#   (Elapsed time: 0.249635537s)
# ===================================================
# =======================================================
#   Infomap v2.7.1 starts at 2024-06-01 21:37:00
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
#                     num-trials = 15
# =======================================================
#   OpenMP 201511 detected with 16 threads...
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1.000000000, sum link flow: 1.000000000
# Build internal network with 257 nodes and 11224 links...
#   -> One-level codelength: 6.706150510
#
# ================================================
# Trial 1/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.30% 0.33%
# Partitioned to codelength 0.277967395 + 6.251974732 = 6.529942127 in 5 (4 non-trivial) modules.
# Super-level compression: to codelength 6.529942127 in 5 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.529942127
#
# => Trial 1/15 finished in 0.011473057s with codelength 6.529942127
#
# ================================================
# Trial 2/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.07% 0.05%
# Partitioned to codelength 0.313601557 + 6.250100789 = 6.563702346 in 7 (6 non-trivial) modules.
# Super-level compression: to codelength 6.563702346 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.563702346
#
# => Trial 2/15 finished in 0.015292876s with codelength 6.563702346
#
# ================================================
# Trial 3/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 1.87% 0.80%
# Partitioned to codelength 0.336257291 + 6.191908857 = 6.528166148 in 6 (5 non-trivial) modules.
# Super-level compression: to codelength 6.528166148 in 6 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.528166148
#
# => Trial 3/15 finished in 0.015574877s with codelength 6.528166148
#
# ================================================
# Trial 4/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.08% 0.56%
# Partitioned to codelength 0.278049897 + 6.252015840 = 6.530065737 in 5 (4 non-trivial) modules.
# Super-level compression: to codelength 6.530065737 in 5 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.530065737
#
# => Trial 4/15 finished in 0.015040875s with codelength 6.530065737
#
# ================================================
# Trial 5/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 1.85% 0.28%
# Partitioned to codelength 0.435800738 + 6.127696090 = 6.563496827 in 5 (4 non-trivial) modules.
# Super-level compression: to codelength 6.563496827 in 5 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.563496827
#
# => Trial 5/15 finished in 0.014853873s with codelength 6.563496827
#
# ================================================
# Trial 6/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 1.94% 0.17%
# Partitioned to codelength 0.299541821 + 6.265136726 = 6.564678546 in 7 (6 non-trivial) modules.
# Super-level compression: to codelength 6.564678546 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.564678546
#
# => Trial 6/15 finished in 0.017026584s with codelength 6.564678546
#
# ================================================
# Trial 7/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.17% 0.47%
# Partitioned to codelength 0.380733070 + 6.149146631 = 6.529879701 in 8 (7 non-trivial) modules.
# Super-level compression: to codelength 6.529879701 in 8 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.529879701
#
# => Trial 7/15 finished in 0.015207175s with codelength 6.529879701
#
# ================================================
# Trial 8/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 1.90% 0.17%
# Partitioned to codelength 0.282712179 + 6.284578501 = 6.56729068 in 7 (6 non-trivial) modules.
# Super-level compression: to codelength 6.56729068 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.56729068
#
# => Trial 8/15 finished in 0.019353896s with codelength 6.567290680
#
# ================================================
# Trial 9/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.23% 0.49%
# Partitioned to codelength 0.398254182 + 6.126450157 = 6.524704339 in 7 (6 non-trivial) modules.
# Super-level compression: to codelength 6.524704339 in 7 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.524704339
#
# => Trial 9/15 finished in 0.014430471s with codelength 6.524704339
#
# ================================================
# Trial 10/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.22% 0.45%
# Partitioned to codelength 0.293176355 + 6.234891030 = 6.528067385 in 6 (5 non-trivial) modules.
# Super-level compression: to codelength 6.528067385 in 6 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.528067385
#
# => Trial 10/15 finished in 0.017487586s with codelength 6.528067385
#
# ================================================
# Trial 11/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 1.78% 0.25%
# Partitioned to codelength 0.267157319 + 6.302941430 = 6.570098749 in 6 (5 non-trivial) modules.
# Super-level compression: to codelength 6.570098749 in 6 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.570098749
#
# => Trial 11/15 finished in 0.019608798s with codelength 6.570098749
#
# ================================================
# Trial 12/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.18% 0.45%
# Partitioned to codelength 0.278049897 + 6.252015840 = 6.530065737 in 5 (4 non-trivial) modules.
# Super-level compression: to codelength 6.530065737 in 5 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.530065737
#
# => Trial 12/15 finished in 0.015132175s with codelength 6.530065737
#
# ================================================
# Trial 13/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.30% 0.36%
# Partitioned to codelength 0.334909014 + 6.193568857 = 6.528477871 in 6 (5 non-trivial) modules.
# Super-level compression: to codelength 6.528477871 in 6 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.528477871
#
# => Trial 13/15 finished in 0.013756768s with codelength 6.528477871
#
# ================================================
# Trial 14/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.00% 0.18%
# Partitioned to codelength 0.464874056 + 6.095745195 = 6.560619251 in 6 (5 non-trivial) modules.
# Super-level compression: to codelength 6.560619251 in 6 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.560619251
#
# => Trial 14/15 finished in 0.010924954s with codelength 6.560619251
#
# ================================================
# Trial 15/15 starting at 2024-06-01 21:37:00
# ================================================
# Two-level compression: 2.01% 0.12%
# Partitioned to codelength 0.435800738 + 6.127696090 = 6.563496827 in 5 (4 non-trivial) modules.
# Super-level compression: to codelength 6.563496827 in 5 top modules.
#
# Recursive sub-structure compression: 0.000000000% . Found 2 levels with codelength 6.563496827
#
# => Trial 15/15 finished in 0.014168270s with codelength 6.563496827
#
#
# ================================================
# Summary after 15 trials
# ================================================
#
#  -> Initiated to codelength 6.524704339 in 2 levels with 7 top modules.
# Codelengths: [6.529942127, 6.563702346, 6.528166148, 6.530065737, 6.563496827, 6.564678546, 6.529879701, 6.567290680, 6.524704339, 6.528067385, 6.570098749, 6.530065737, 6.528477871, 6.560619251, 6.563496827]
# [min, average, max] codelength: [6.524704339, 6.545516818, 6.570098749]
#
# Best end modular solution in 2 levels:
# Per level number of modules:         [          7,           0] (sum: 7)
# Per level number of leaf nodes:      [          0,         257] (sum: 257)
# Per level average child degree:      [          7,     36.7143] (average: 35.926406926)
# Per level codelength for modules:    [0.398254182, 0.000000000] (sum: 0.398254182)
# Per level codelength for leaf nodes: [0.000000000, 6.126450157] (sum: 6.126450157)
# Per level codelength total:          [0.398254182, 6.126450157] (sum: 6.524704339)
#
# ===================================================
#   Infomap ends at 2024-06-01 21:37:00
#   (Elapsed time: 0.243993509s)
# ===================================================

# %%
def save_partition_togeo(partition, filename):
    for i, comm in enumerate(partition):
        for node in comm:
            geo.loc[geo["geo_id"]==node,"community"] = str(i)
    geo[["geo_id","community"]].to_csv(f"data/geo_community/geo_community_{filename}.csv" ,index=False)

def save_two_algorithm_community(G_community_dict,filename):
    save_partition_togeo(G_community_dict["Louvain"],f"{filename}_Louvain")
    save_partition_togeo(G_community_dict["Infomap"],f"{filename}_Infomap")

# %%
save_two_algorithm_community(G_total_community_dict,"Total")
save_two_algorithm_community(G_earlymorning_community_dict,"Early Morning")
save_two_algorithm_community(G_morningrush_community_dict,"Morning Rush")
save_two_algorithm_community(G_morningtonoon_community_dict,"Morning to Noon")
save_two_algorithm_community(G_afternoon_community_dict,"Afternoon")
save_two_algorithm_community(G_eveningrush_community_dict,"Evening Rush")
save_two_algorithm_community(G_night_community_dict,"Night")

# %%
# geo["community"].value_counts()
